# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17493, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 17493 (delta 1), reused 0 (delta 0), pack-reused 17490 (from 3)
# Receiving objects: 100% (17493/17493), 16.59 MiB | 10.65 MiB/s, done.
# Resolving deltas: 100% (11992/11992), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class_names = ['raw', 'middle', 'mature']  # 必要に応じて変更

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-156242b7-7e36-4ca1-819e-562d4fb181cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-156242b7-7e36-4ca1-819e-562d4fb181cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

# 解凍先ディレクトリを作成
os.makedirs("dataset", exist_ok=True)

# 解凍処理
with zipfile.ZipFile("dataset.zip", 'r') as zip_ref:
    zip_ref.extractall("dataset")

# 解凍された内容を確認（オプション）
# !ls dataset
# Out:
# dataset

# %%
import yaml

class_names = ['raw', 'middle', 'mature']  # ラベルに応じて変更

data = {
    'train': 'dataset/images/train',
    'val': 'dataset/images/val',
    'nc': len(class_names),
    'names': class_names
}

with open('dataset/data.yaml', 'w') as f:
    yaml.dump(data, f)

# 内容確認
# !cat dataset/data.yaml
# Out:
# names:
# - raw
# - middle
# - mature
# nc: 3
# train: dataset/images/train
# val: dataset/images/val

# %%
# !ls -R /content
# Out:
# /content:
# drive  sample_data  yolov5
#
# /content/drive:
# MyDrive
#
# /content/drive/MyDrive:
# 'Colab Notebooks'   compost_dataset   compost_model.h5	 Untitled0.ipynb
#
# '/content/drive/MyDrive/Colab Notebooks':
#  btc_ooba.ipynb		       'Untitled (2)'	  Untitled6.ipynb
#  systoku_ep3_01_mnist.ipynb     Untitled2.ipynb   Untitled7.ipynb
#  systoku_ep3_02_cifar10.ipynb  'Untitled (3)'	  Untitled8.ipynb
#  systoku_ep3_03_yolov5.ipynb    Untitled3.ipynb   Untitled9.ipynb
#  Untitled		       'Untitled (4)'	  YOLOv5.ipynb
#  Untitled0.ipynb	        Untitled4.ipynb   yolov8n.ipynb
# 'Untitled (1)'		       'Untitled (5)'
#  Untitled1.ipynb	        Untitled5.ipynb
#
# /content/drive/MyDrive/compost_dataset:
# images	labels
#
# /content/drive/MyDrive/compost_dataset/images:
# train  val
#
# /content/drive/MyDrive/compost_dataset/images/train:
# compost_mature_10.jpg  compost_middle_3.jpg  compost_raw_1.jpg
# compost_mature_7.jpg   compost_middle_4.jpg  compost_raw_2.jpg
# ...

# %%
import yaml

class_names = ['raw', 'middle', 'mature']  # ← 実際のラベル順に調整してください

data = {
    'train': 'dataset/dataset/images/train',
    'val': 'dataset/dataset/images/val',
    'nc': len(class_names),
    'names': class_names
}

with open('dataset/data.yaml', 'w') as f:
    yaml.dump(data, f)

# 確認
# !cat dataset/data.yaml
# Out:
# names:
# - raw
# - middle
# - mature
# nc: 3
# train: dataset/dataset/images/train
# val: dataset/dataset/images/val

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data dataset/data.yaml --weights yolov5s.pt --name compost_detect
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-06-18 04:23:09.670655: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750220589.979232    1529 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
ls runs/train/
# Out:
# compost_detect/

# %%
from IPython.display import Image
Image('runs/train/compost_detect/results.png')

# %%
# !python detect.py --weights runs/train/compost_detect/weights/best.pt --img 640 --conf 0.25 --source dataset/dataset/images/val
# Out:
# detect: weights=['runs/train/compost_detect/weights/best.pt'], source=dataset/dataset/images/val, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-421-g79c4c31d Python-3.11.13 torch-2.6.0+cu124 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/6 /content/yolov5/dataset/dataset/images/val/compost_val1.jpg: 576x640 (no detections), 602.5ms
# image 2/6 /content/yolov5/dataset/dataset/images/val/compost_val2.jpg: 640x576 (no detections), 560.3ms
# ...

# %%
from glob import glob
import matplotlib.pyplot as plt
import cv2

imgs = glob('runs/detect/exp2/*.jpg')
for img_path in imgs[:6]:  # 6枚だけ表示
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.axis('off')
    plt.show()
